# %%
import pandas as pd

dataset1 = pd.read_csv('general_data.csv')
dataset1.drop_duplicates()
# Out:
#       Age Attrition     BusinessTravel              Department  \
# 0      51        No      Travel_Rarely                   Sales
# 1      31       Yes  Travel_Frequently  Research & Development
# 2      32        No  Travel_Frequently  Research & Development
# 3      38        No         Non-Travel  Research & Development
# 4      32        No      Travel_Rarely  Research & Development
# ...   ...       ...                ...                     ...
# 4405   42        No      Travel_Rarely  Research & Development
# 4406   29        No      Travel_Rarely  Research & Development
# 4407   25        No      Travel_Rarely  Research & Development
# 4408   42        No      Travel_Rarely                   Sales
# 4409   40        No      Travel_Rarely  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 0                    6          2  Life Sciences              1           1
# ...

# %%
dataset1.dropna()
# Out:
#       Age Attrition     BusinessTravel              Department  \
# 0      51        No      Travel_Rarely                   Sales
# 1      31       Yes  Travel_Frequently  Research & Development
# 2      32        No  Travel_Frequently  Research & Development
# 3      38        No         Non-Travel  Research & Development
# 4      32        No      Travel_Rarely  Research & Development
# ...   ...       ...                ...                     ...
# 4404   29        No      Travel_Rarely                   Sales
# 4405   42        No      Travel_Rarely  Research & Development
# 4406   29        No      Travel_Rarely  Research & Development
# 4407   25        No      Travel_Rarely  Research & Development
# 4408   42        No      Travel_Rarely                   Sales
#
#       DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 0                    6          2  Life Sciences              1           1
# ...

# %%
dataset3 = dataset1.dropna()
dataset3
# Out:
#       Age Attrition     BusinessTravel              Department  \
# 0      51         0      Travel_Rarely                   Sales
# 1      31         1  Travel_Frequently  Research & Development
# 2      32         0  Travel_Frequently  Research & Development
# 3      38         0         Non-Travel  Research & Development
# 4      32         0      Travel_Rarely  Research & Development
# ...   ...       ...                ...                     ...
# 4404   29        No      Travel_Rarely                   Sales
# 4405   42        No      Travel_Rarely  Research & Development
# 4406   29        No      Travel_Rarely  Research & Development
# 4407   25        No      Travel_Rarely  Research & Development
# 4408   42        No      Travel_Rarely                   Sales
#
#       DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 0                    6          2  Life Sciences              1           1
# ...

# %%
dataset3.Attrition[dataset3.Attrition=='Yes'] = 1
dataset3.Attrition[dataset3.Attrition=='No'] = 0
print(dataset3)
# Out:
#       Age Attrition     BusinessTravel              Department  \
# 0      51         0      Travel_Rarely                   Sales
# 1      31         1  Travel_Frequently  Research & Development
# 2      32         0  Travel_Frequently  Research & Development
# 3      38         0         Non-Travel  Research & Development
# 4      32         0      Travel_Rarely  Research & Development
# ...   ...       ...                ...                     ...
# 4404   29         0      Travel_Rarely                   Sales
# 4405   42         0      Travel_Rarely  Research & Development
# 4406   29         0      Travel_Rarely  Research & Development
# 4407   25         0      Travel_Rarely  Research & Development
# 4408   42         0      Travel_Rarely                   Sales
#
#       DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 0                    6          2  Life Sciences              1           1
# ...

# %%
from scipy.stats import pearsonr
stats,p =pearsonr(dataset3.Attrition, dataset3.Age)
print(stats,p)
if (p>0.05):
    print("Null Hypothesis Rejected and Alternative Hypothesis Accepted")
    print("There is correlation between Attrition and Age")
elif(p<0.05):
    print("Null Hypothesis Accepted and Alternative Hypothesis Rejected")
    print("There is no correlation between Attrition and Age")
# Out:
# -0.15839867954096148 5.126598219399243e-26
# Null Hypothesis Accepted and Alternative Hypothesis Rejected
# There is no correlation between Attrition and Age

# %%
dataset3.corr()
# Out:
#                               Age  DistanceFromHome  Education  EmployeeCount  \
# Age                      1.000000          0.007376  -0.033900            NaN
# DistanceFromHome         0.007376          1.000000  -0.007491            NaN
# Education               -0.033900         -0.007491   1.000000            NaN
# EmployeeCount                 NaN               NaN        NaN            NaN
# EmployeeID               0.008105         -0.000326  -0.009389            NaN
# JobLevel                -0.001137         -0.039990   0.045822            NaN
# MonthlyIncome           -0.045163         -0.022757   0.007289            NaN
# NumCompaniesWorked       0.299527         -0.014449  -0.016210            NaN
# PercentSalaryHike       -0.032561          0.037720  -0.041054            NaN
# StandardHours                 NaN               NaN        NaN            NaN
# StockOptionLevel        -0.031504          0.009353   0.002386            NaN
# ...

# %%
# Attrition and DistanceFromHome
from scipy.stats import pearsonr
stats,p =pearsonr(dataset3.Attrition, dataset3.DistanceFromHome)
print(stats,p)
if (p>0.05):
    print("Null Hypothesis Rejected and Alternative Hypothesis Accepted")
    print("There is correlation between Attrition and DistanceFromHome")
elif(p<0.05):
    print("Null Hypothesis Accepted and Alternative Hypothesis Rejected")
    print("There is no correlation between Attrition and DistanceFromHome")
# Out:
# -0.009448638515156007 0.5317715668019634
# Null Hypothesis Rejected and Alternative Hypothesis Accepted
# There is correlation between Attrition and DistanceFromHome

# %%
# Attrition and Education
from scipy.stats import pearsonr
stats,p =pearsonr(dataset3.Attrition, dataset3.Education)
print(stats,p)
if (p>0.05):
    print("Null Hypothesis Rejected and Alternative Hypothesis Accepted")
    print("There is correlation between Attrition and Education")
elif(p<0.05):
    print("Null Hypothesis Accepted and Alternative Hypothesis Rejected")
    print("There is no correlation between Attrition and Education")
# Out:
# -0.017106307050278116 0.2575753930816995
# Null Hypothesis Rejected and Alternative Hypothesis Accepted
# There is correlation between Attrition and Education

# %%
# Attrition and JobLevel
from scipy.stats import pearsonr
stats,p =pearsonr(dataset3.Attrition, dataset3.JobLevel)
print(stats,p)
if (p>0.05):
    print("Null Hypothesis Rejected and Alternative Hypothesis Accepted")
    print("There is correlation between Attrition and JobLevel")
elif(p<0.05):
    print("Null Hypothesis Accepted and Alternative Hypothesis Rejected")
    print("There is no correlation between Attrition and JobLevel")
# Out:
# -0.012381569720790164 0.4125489150377358
# Null Hypothesis Rejected and Alternative Hypothesis Accepted
# There is correlation between Attrition and JobLevel

# %%
# Attrition and MonthlyIncome
from scipy.stats import pearsonr
stats,p =pearsonr(dataset3.Attrition, dataset3.MonthlyIncome)
print(stats,p)
if (p>0.05):
    print("Null Hypothesis Rejected and Alternative Hypothesis Accepted")
    print("There is correlation between Attrition and MonthlyIncome")
elif(p<0.05):
    print("Null Hypothesis Accepted and Alternative Hypothesis Rejected")
    print("There is no correlation between Attrition and MonthlyIncome")
# Out:
# -0.030160293808459575 0.04589086274474114
# Null Hypothesis Accepted and Alternative Hypothesis Rejected
# There is no correlation between Attrition and MonthlyIncome

# %%
# Attrition and NumCompaniesWorked
from scipy.stats import pearsonr
stats,p =pearsonr(dataset3.Attrition, dataset3.NumCompaniesWorked)
print(stats,p)
if (p>0.05):
    print("Null Hypothesis Rejected and Alternative Hypothesis Accepted")
    print("There is correlation between Attrition and NumCompaniesWorked")
elif(p<0.05):
    print("Null Hypothesis Accepted and Alternative Hypothesis Rejected")
    print("There is no correlation between Attrition and NumCompaniesWorked")
# Out:
# 0.042830567244719 0.004572057121625154
# Null Hypothesis Accepted and Alternative Hypothesis Rejected
# There is no correlation between Attrition and NumCompaniesWorked

# %%
# Attrition and PercentSalaryHike
from scipy.stats import pearsonr
stats,p =pearsonr(dataset3.Attrition, dataset3.PercentSalaryHike)
print(stats,p)
if (p>0.05):
    print("Null Hypothesis Rejected and Alternative Hypothesis Accepted")
    print("There is correlation between Attrition and PercentSalaryHike")
elif(p<0.05):
    print("Null Hypothesis Accepted and Alternative Hypothesis Rejected")
    print("There is no correlation between Attrition and PercentSalaryHike")
# Out:
# 0.03315303713546523 0.028192446935107012
# Null Hypothesis Accepted and Alternative Hypothesis Rejected
# There is no correlation between Attrition and PercentSalaryHike

# %%
# Attrition and StockOptionLevel
from scipy.stats import pearsonr
stats,p =pearsonr(dataset3.Attrition, dataset3.StockOptionLevel)
print(stats,p)
if (p>0.05):
    print("Null Hypothesis Rejected and Alternative Hypothesis Accepted")
    print("There is correlation between Attrition and StockOptionLevel")
elif(p<0.05):
    print("Null Hypothesis Accepted and Alternative Hypothesis Rejected")
    print("There is no correlation between Attrition and StockOptionLevel")
# Out:
# -0.008164026684984026 0.5889996358312328
# Null Hypothesis Rejected and Alternative Hypothesis Accepted
# There is correlation between Attrition and StockOptionLevel

# %%
# Attrition and TotalWorkingYears
from scipy.stats import pearsonr
stats,p =pearsonr(dataset3.Attrition, dataset3.TotalWorkingYears)
print(stats,p)
if (p>0.05):
    print("Null Hypothesis Rejected and Alternative Hypothesis Accepted")
    print("There is correlation between Attrition and TotalWorkingYears")
elif(p<0.05):
    print("Null Hypothesis Accepted and Alternative Hypothesis Rejected")
    print("There is no correlation between Attrition and TotalWorkingYears")
# Out:
# -0.16966991684723273 1.1645434967147956e-29
# Null Hypothesis Accepted and Alternative Hypothesis Rejected
# There is no correlation between Attrition and TotalWorkingYears

# %%
# Attrition and TrainingTimesLastYear
from scipy.stats import pearsonr
stats,p =pearsonr(dataset3.Attrition, dataset3.TrainingTimesLastYear)
print(stats,p)
if (p>0.05):
    print("Null Hypothesis Rejected and Alternative Hypothesis Accepted")
    print("There is correlation between Attrition and TrainingTimesLastYear")
elif(p<0.05):
    print("Null Hypothesis Accepted and Alternative Hypothesis Rejected")
    print("There is no correlation between Attrition and TrainingTimesLastYear")
# Out:
# -0.047585736930815525 0.0016276603635481809
# Null Hypothesis Accepted and Alternative Hypothesis Rejected
# There is no correlation between Attrition and TrainingTimesLastYear

# %%
# Attrition and YearsAtCompany
from scipy.stats import pearsonr
stats,p =pearsonr(dataset3.Attrition, dataset3.YearsAtCompany)
print(stats,p)
if (p>0.05):
    print("Null Hypothesis Rejected and Alternative Hypothesis Accepted")
    print("There is correlation between Attrition and YearsAtCompany")
elif(p<0.05):
    print("Null Hypothesis Accepted and Alternative Hypothesis Rejected")
    print("There is no correlation between Attrition and YearsAtCompany")
# Out:
# -0.13300261842521083 9.476118084864852e-19
# Null Hypothesis Accepted and Alternative Hypothesis Rejected
# There is no correlation between Attrition and YearsAtCompany

# %%
# Attrition and YearsSinceLastPromotion
from scipy.stats import pearsonr
stats,p =pearsonr(dataset3.Attrition, dataset3.YearsSinceLastPromotion)
print(stats,p)
if (p>0.05):
    print("Null Hypothesis Rejected and Alternative Hypothesis Accepted")
    print("There is correlation between Attrition and YearsSinceLastPromotion")
elif(p<0.05):
    print("Null Hypothesis Accepted and Alternative Hypothesis Rejected")
    print("There is no correlation between Attrition and YearsSinceLastPromotion")
# Out:
# -0.03142315056330794 0.03752293607393637
# Null Hypothesis Accepted and Alternative Hypothesis Rejected
# There is no correlation between Attrition and YearsSinceLastPromotion

# %%
# Attrition and YearsWithCurrManager
from scipy.stats import pearsonr
stats,p =pearsonr(dataset3.Attrition, dataset3.YearsWithCurrManager)
print(stats,p)
if (p>0.05):
    print("Null Hypothesis Rejected and Alternative Hypothesis Accepted")
    print("There is correlation between Attrition and YearsWithCurrManager")
elif(p<0.05):
    print("Null Hypothesis Accepted and Alternative Hypothesis Rejected")
    print("There is no correlation between Attrition and YearsWithCurrManager")
# Out:
# -0.154691536902868 7.1053696467956645e-25
# Null Hypothesis Accepted and Alternative Hypothesis Rejected
# There is no correlation between Attrition and YearsWithCurrManager
